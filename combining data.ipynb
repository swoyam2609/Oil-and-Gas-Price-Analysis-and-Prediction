# %%
import pandas as pd

# Read the individual datasets
brent_df = pd.read_csv("brent.csv")
crude_df = pd.read_csv("crude.csv")
heating_df = pd.read_csv("heating.csv")
natural_df = pd.read_csv("natural.csv")

# Merge the datasets vertically side by side based on the 'Date' column
merged_df = pd.concat([brent_df, crude_df, heating_df, natural_df], axis=1)

# %%
merged_df.head()
# Out:
#          Date   Open   High    Low  Close  Volume        Date   Open   High  \
# 0  2000-01-04  23.90  24.70  23.89  24.39   32509  2000-01-04  25.20  25.69
# 1  2000-01-05  24.25  24.37  23.70  23.73   30310  2000-01-05  25.50  25.61
# 2  2000-01-06  23.55  24.22  23.35  23.62   44662  2000-01-06  24.80  25.34
# 3  2000-01-07  23.57  23.98  23.05  23.09   34826  2000-01-07  24.65  25.00
# 4  2000-01-10  23.04  23.78  23.04  23.73   26388  2000-01-10  24.22  24.75
#
#      Low  ...    High     Low   Close   Volume        Date   Open   High  \
# 0  24.71  ...  0.6830  0.6540  0.6778  25311.0  2000-01-04  2.130  2.200
# 1  24.87  ...  0.6790  0.6650  0.6655  18691.0  2000-01-05  2.180  2.200
# 2  24.51  ...  0.6830  0.6550  0.6628  27082.0  2000-01-06  2.165  2.220
# 3  24.15  ...  0.6710  0.6460  0.6475  26320.0  2000-01-07  2.195  2.230
# 4  24.02  ...  0.6535  0.6355  0.6472  20721.0  2000-01-10  2.180  2.255
#
#      Low  Close   Volume
# 0  2.130  2.176  30152.0
# ...

# %%
import pandas as pd

# Read the individual datasets
brent_df = pd.read_csv("brent.csv")
crude_df = pd.read_csv("crude.csv")
heating_df = pd.read_csv("heating.csv")
natural_df = pd.read_csv("natural.csv")

# %%
merged_df = pd.merge(brent_df, crude_df, on='Date')

# %%
merged_df
# Out:
#             Date  OpenBrent  HighBrent  LowBrent  CloseBrent  VolumeBrent  \
# 0     2000-01-04      23.90      24.70     23.89       24.39        32509
# 1     2000-01-05      24.25      24.37     23.70       23.73        30310
# 2     2000-01-06      23.55      24.22     23.35       23.62        44662
# 3     2000-01-07      23.57      23.98     23.05       23.09        34826
# 4     2000-01-10      23.04      23.78     23.04       23.73        26388
# ...          ...        ...        ...       ...         ...          ...
# 5607  2022-06-10     122.89     124.33    119.81      122.01       294278
# 5608  2022-06-13     121.94     123.70    118.93      122.27       257105
# 5609  2022-06-14     121.88     125.19    118.91      121.17       291264
# 5610  2022-06-15     120.79     121.88    117.75      118.51       231061
# 5611  2022-06-16     119.65     120.29    115.56      119.81       276675
#
#       OpenCrude  HighCrude  LowCrude  CloseCrude  VolumeCrude
# ...

# %%
merged_df = pd.merge(merged_df, heating_df, on='Date')

# %%
merged_df
# Out:
#             Date  OpenBrent  HighBrent  LowBrent  CloseBrent  VolumeBrent  \
# 0     2000-01-04      23.90      24.70     23.89       24.39        32509
# 1     2000-01-05      24.25      24.37     23.70       23.73        30310
# 2     2000-01-06      23.55      24.22     23.35       23.62        44662
# 3     2000-01-07      23.57      23.98     23.05       23.09        34826
# 4     2000-01-10      23.04      23.78     23.04       23.73        26388
# ...          ...        ...        ...       ...         ...          ...
# 5590  2022-06-10     122.89     124.33    119.81      122.01       294278
# 5591  2022-06-13     121.94     123.70    118.93      122.27       257105
# 5592  2022-06-14     121.88     125.19    118.91      121.17       291264
# 5593  2022-06-15     120.79     121.88    117.75      118.51       231061
# 5594  2022-06-16     119.65     120.29    115.56      119.81       276675
#
#       OpenCrude  HighCrude  LowCrude  CloseCrude  VolumeCrude  OpenHeating  \
# ...

# %%
merged_df = pd.merge(merged_df, natural_df, on='Date')

# %%
merged_df.head()
# Out:
#          Date  OpenBrent  HighBrent  LowBrent  CloseBrent  VolumeBrent  \
# 0  2000-01-04      23.90      24.70     23.89       24.39        32509
# 1  2000-01-05      24.25      24.37     23.70       23.73        30310
# 2  2000-01-06      23.55      24.22     23.35       23.62        44662
# 3  2000-01-07      23.57      23.98     23.05       23.09        34826
# 4  2000-01-10      23.04      23.78     23.04       23.73        26388
#
#    OpenCrude  HighCrude  LowCrude  CloseCrude  ...  OpenHeating  HighHeating  \
# 0      25.20      25.69     24.71       25.55  ...       0.6720       0.6830
# 1      25.50      25.61     24.87       24.91  ...       0.6790       0.6790
# 2      24.80      25.34     24.51       24.78  ...       0.6645       0.6830
# 3      24.65      25.00     24.15       24.22  ...       0.6600       0.6710
# 4      24.22      24.75     24.02       24.67  ...       0.6445       0.6535
#
#    LowHeating  CloseHeating  VolumeHeating  OpenNatural  HighNatural  \
# ...

# %%
merged_df['Date'] = pd.to_datetime(merged_df['Date'])

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5588 entries, 0 to 5587
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           5588 non-null   datetime64[ns]
#  1   OpenBrent      5588 non-null   float64
#  2   HighBrent      5588 non-null   float64
#  3   LowBrent       5588 non-null   float64
#  4   CloseBrent     5588 non-null   float64
#  5   VolumeBrent    5588 non-null   int64
#  6   OpenCrude      5588 non-null   float64
#  7   HighCrude      5588 non-null   float64
#  8   LowCrude       5588 non-null   float64
#  9   CloseCrude     5588 non-null   float64
#  10  VolumeCrude    5588 non-null   int64
#  11  OpenHeating    5588 non-null   float64
#  12  HighHeating    5588 non-null   float64
#  13  LowHeating     5588 non-null   float64
#  14  CloseHeating   5588 non-null   float64
#  15  VolumeHeating  5588 non-null   int64
#  16  OpenNatural    5588 non-null   float64
# ...

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure(figsize=(18, 5))
plt.plot(merged_df['Date'], merged_df['VolumeBrent'], label='Brent')
plt.plot(merged_df['Date'], merged_df['VolumeCrude'], label='Crude')
plt.plot(merged_df['Date'], merged_df['VolumeHeating'], label='Heating')
plt.plot(merged_df['Date'], merged_df['VolumeNatural'], label='Natural')
plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(18, 5))
plt.plot(merged_df['Date'], merged_df['OpenBrent'], label='Brent')
plt.plot(merged_df['Date'], merged_df['OpenCrude'], label='Crude')
plt.plot(merged_df['Date'], merged_df['OpenHeating'], label='Heating')
plt.plot(merged_df['Date'], merged_df['OpenNatural'], label='Natural')
plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(18, 5))
plt.plot(merged_df['Date'], merged_df['HighBrent'], label='Brent')
plt.plot(merged_df['Date'], merged_df['HighCrude'], label='Crude')
plt.plot(merged_df['Date'], merged_df['HighHeating'], label='Heating')
plt.plot(merged_df['Date'], merged_df['HighNatural'], label='Natural')
plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(18, 5))
plt.plot(merged_df['Date'], merged_df['CloseBrent'], label='Brent')
plt.plot(merged_df['Date'], merged_df['CloseCrude'], label='Crude')
plt.plot(merged_df['Date'], merged_df['CloseHeating'], label='Heating')
plt.plot(merged_df['Date'], merged_df['CloseNatural'], label='Natural')
plt.legend()
plt.show()

# %%
merged_df.corr()
# Out:
# /var/folders/pc/9c01j4c97lj6kf65dsrjqm0w0000gn/T/ipykernel_61954/4191659586.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   merged_df.corr()
#                OpenBrent  HighBrent  LowBrent  CloseBrent  VolumeBrent  \
# OpenBrent       1.000000   0.999519  0.999391    0.998954     0.308884
# HighBrent       0.999519   1.000000  0.999189    0.999430     0.312670
# LowBrent        0.999391   0.999189  1.000000    0.999575     0.303514
# CloseBrent      0.998954   0.999430  0.999575    1.000000     0.306981
# VolumeBrent     0.308884   0.312670  0.303514    0.306981     1.000000
# OpenCrude       0.983384   0.983147  0.982574    0.982370     0.240224
# HighCrude       0.982642   0.983336  0.982039    0.982556     0.243369
# LowCrude        0.982949   0.982989  0.983369    0.983211     0.236680
# ...

# %%
merged_df.to_csv('merged.csv', index=False)
